# %%
import blaze
import odo
import datashape
import pandas

# %%
bz = blaze.data('blaze://139.57.169.205:6363')

# %%
dt = odo.odo(bz.t_play_by_play_o_2016, pandas.DataFrame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f126f933129a> in <module>()
# ----> 1 dt = odo.odo(bz.t_play_by_play_o_2016, pandas.DataFrame)
#
# /home/kmongeon/miniconda3/envs/blaze-impala/lib/python2.7/site-packages/odo/odo.pyc in odo(source, target, **kwargs)
#      89     odo.append.append      - Add things onto existing things
#      90     """
# ---> 91     return into(target, source, **kwargs)
#
# /home/kmongeon/miniconda3/envs/blaze-impala/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /home/kmongeon/miniconda3/envs/blaze-impala/lib/python2.7/site-packages/blaze/interactive.pyc in into(a, b, **kwargs)
# ...
